# %% [markdown]
# # Should change Tkf below

# %%
import importlib
import time
import os
import pickle
import numpy as np
import scipy as sp
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
from scipy import ndimage
from scipy import integrate
from scipy import interpolate

# %% [markdown]
# # Should change Tkf below

# %%
from multi_loc import covariance, assimilate, utilities

# %%
# %matplotlib inline

# %%
def imshow(X, title=None, vmin=None, vmax=None, cmap=None):
    plt.figure()
    im = plt.imshow(X, vmin=vmin, vmax=vmax, cmap=cmap)
    plt.colorbar(im)
    plt.title(title)

# %%
tune_name = 'fine_obs'

save_dir = 'RK_tune'


save_dir = os.path.join(
    '/home/travisharty/Documents/python_code/multi_loc/notebooks/',
    save_dir)
    
this_path = os.path.join(save_dir, 'Z_GT.npy')
Zgt = np.load(this_path)

this_path = os.path.join(save_dir, 'Z0_ens.npy')
Z0ens = np.load(this_path)

this_path = os.path.join(save_dir, 't_gt.npy')
t_gt = np.load(this_path)

this_path = os.path.join(save_dir, 't_lr.npy')
t_lr = np.load(this_path)

this_path = os.path.join(save_dir, 'run_vars.pkl')
with open(this_path, mode='rb') as f:
    run_vars = pickle.load(f)

# %%
for key, value in run_vars.items():
    print(key + ' = ' + str(value))
    exec(key + '=value')
# Out:
# Nz = 960
# K = 32
# I = 12
# F = 15.0
# b = 10.0
# c = 2.5
# alpha = 0.12414383561643835
# beta = 0.013746194824961947
# coarse = 8
# Nez = 20
# Nex = 500
# dt_rk = 0.004166666666666667
# dt_lr = 0.1
# dt_gt = 0.0020833333333333333
# Tic = 24.0
# Tlr = 4000
# Tgt = 250

# %% [markdown]
# # Should change Tkf below

# %%
tune_dir = os.path.join(save_dir, tune_name)
if not os.path.exists(tune_dir):
    os.mkdir(tune_dir)

dt_trial_rk = 0.05/24
dt_kf = 0.05
dt_save = None
Tkf = Tgt/5     ######## Change this (I forgot) #######
Tspin_index = 500
Tspin = dt_kf * Tspin_index

alpha_range = np.array([0, 0.01, 0.02, 0.04, 0.08], dtype='float')
loc_range = np.array([5, 10, 15, 20, 30, 40, 50, 60], dtype='float')


R_sd = 2
everyH = 24
Hz = np.eye(Nz)[::everyH]
Ny = Hz.shape[0]
Rz = np.eye(Ny) * R_sd**2

fine_obs_dict = {'dt_trial_rk': dt_trial_rk,
                 'dt_kf': dt_kf,
                 'dt_save': dt_save,
                 'Tkf': Tkf,
                 'Tspin': Tspin,
                 'alpha_range': alpha_range,
                 'loc_range': loc_range,
                 'R_sd': R_sd,
                 'everyH': everyH,
                 'Hz': Hz,
                 'Rz': Rz}

this_path = os.path.join(tune_dir, 'fine_obs_dict.pkl')
with open(this_path, mode='wb') as f:
    pickle.dump(fine_obs_dict, f)

# %%
Nobs = int(Tkf/dt_kf) + 1
t_kf = np.linspace(0, Tkf, Nobs)

Ngt = int(Tgt/dt_gt) + 1
t_gt = np.linspace(0, Tgt, Ngt)
index_Tkf = int(Tkf/dt_gt) + 1

every_t = int(dt_kf/dt_gt)

if not np.allclose(t_kf, t_gt[0:index_Tkf:every_t]):
    print('They do not match')

# %%
Zloc = np.arange(Nz)

Zgt_ts = xr.DataArray(Zgt[:, 0:index_Tkf:every_t],
                      dims=('loc', 'time'),
                      coords={'loc': Zloc,
                              'time': t_kf})
Zobs_ts = Zgt[::everyH, 0:index_Tkf:every_t]
Zobs_ts = xr.DataArray(Zobs_ts,
                       dims=('loc', 'time'),
                       coords={'loc': Zloc[::everyH],
                               'time': t_kf})
del Zgt

# %%
importlib.reload(assimilate)
importlib.reload(utilities)


rmse_array_f = np.ones([alpha_range.size, loc_range.size]) * np.nan
std_array_f = rmse_array_f.copy()

rmse_array_a = rmse_array_f.copy()
std_array_a = rmse_array_f.copy()

stdrd_dir = os.path.join(tune_dir, 'stdrd_loc')
if not os.path.exists(stdrd_dir):
    os.mkdir(stdrd_dir)

for alpha_count, this_alpha in enumerate(alpha_range):
    for loc_count, this_loc in enumerate(loc_range):
        this_folder_name = f'inf_{alpha_count:04}_loc_{loc_count:04}'
        this_dir_name = os.path.join(stdrd_dir, this_folder_name)
        if not os.path.exists(this_dir_name):
            os.mkdir(this_dir_name)
        print('alpha: ', this_alpha, '; loc: ', this_loc)
        print(this_dir_name)

        rho_Zc = np.arange(Nz)
        rho_Zc = np.minimum(np.abs(Nz - rho_Zc)%Nz, rho_Zc)
        rho_Zc = np.exp(-(rho_Zc**2)/(2*this_loc**2))
        rho_Zc = sp.linalg.circulant(rho_Zc)
#         imshow(rho_Zc)
        
        this_path = os.path.join(this_dir_name, 'rho0z')
        np.save(this_path, this_loc)
        
        this_path = os.path.join(this_dir_name, 'alpha')
        np.save(this_path, this_alpha)

        cycle_dict = {'Z0ens': Z0ens,
                      'Zobs_ts': Zobs_ts,
                      'Rz': Rz, 'Hz': Hz,
                      'Tkf': Tkf,
                      'dt_kf': dt_kf,
                      'dt_rk': dt_trial_rk,
                      'rho_Z': rho_Zc,
                      'rho0_Z': this_loc,
                      'alpha': this_alpha}
        try:
            returned_dict = assimilate.cycle_KF_LM3_stdrd(**cycle_dict)
            mu_f = returned_dict['mu_f']
            std_f = returned_dict['std_f']

            mu_a = returned_dict['mu_a']
            std_a = returned_dict['std_a']

            this_path = os.path.join(this_dir_name, 'mu_f.nc')
            mu_f.to_netcdf(this_path)

            this_path = os.path.join(this_dir_name, 'std_f.nc')
            std_f.to_netcdf(this_path)

            this_path = os.path.join(this_dir_name, 'mu_a.nc')
            mu_a.to_netcdf(this_path)

            this_path = os.path.join(this_dir_name, 'std_a.nc')
            std_a.to_netcdf(this_path)


            rmse_array_f[alpha_count, loc_count] = (np.sqrt(
                ((mu_f - Zgt_ts.sel(time=mu_f.time))**2).mean(axis=0))
                                          .isel(time=slice(Tspin_index, None)).mean())
            rmse_array_a[alpha_count, loc_count] = (np.sqrt(
                ((mu_a - Zgt_ts.sel(time=mu_f.time))**2).mean(axis=0))
                                          .isel(time=slice(Tspin_index, None)).mean())
            std_array_f[alpha_count, loc_count] = (np.sqrt((std_f**2).mean(axis=0))
                                                  .isel(time=slice(Tspin_index, None)).mean())
            std_array_a[alpha_count, loc_count] = (np.sqrt((std_a**2).mean(axis=0))
                                                  .isel(time=slice(Tspin_index, None)).mean())
            print('rmse_f: ', rmse_array_f[alpha_count, loc_count])
            print('rmse_a: ', rmse_array_a[alpha_count, loc_count])
        except:
            print(this_dir_name, ' has failed.')
# Out:
# alpha:  0.0 ; loc:  5.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0000_loc_0000
# rmse_f:  1.0625366562145644
# rmse_a:  1.002676538379322
# alpha:  0.0 ; loc:  10.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0000_loc_0001
# rmse_f:  0.6566422307995194
# rmse_a:  0.6069462601634357
# alpha:  0.0 ; loc:  15.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0000_loc_0002
# rmse_f:  0.6089099144956434
# rmse_a:  0.559011610789904
# alpha:  0.0 ; loc:  20.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0000_loc_0003
# rmse_f:  0.6142257917501013
# rmse_a:  0.5631772148423886
# alpha:  0.0 ; loc:  30.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0000_loc_0004
# rmse_f:  0.5960010074368642
# rmse_a:  0.5462208816313484
# alpha:  0.0 ; loc:  40.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0000_loc_0005
# rmse_f:  0.5644398106425303
# rmse_a:  0.5177447792634959
# alpha:  0.0 ; loc:  50.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0000_loc_0006
# rmse_f:  0.5361414467601724
# rmse_a:  0.49224712339872456
# alpha:  0.0 ; loc:  60.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0000_loc_0007
# rmse_f:  0.5550792627803032
# rmse_a:  0.5080177293098854
# alpha:  0.01 ; loc:  5.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0001_loc_0000
# rmse_f:  0.9793531138033511
# rmse_a:  0.922261281570363
# alpha:  0.01 ; loc:  10.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0001_loc_0001
# rmse_f:  0.6191417768888905
# rmse_a:  0.5716895402474891
# alpha:  0.01 ; loc:  15.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0001_loc_0002
# rmse_f:  0.5828747901559193
# rmse_a:  0.534347878314331
# alpha:  0.01 ; loc:  20.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0001_loc_0003
# rmse_f:  0.5799238726745726
# rmse_a:  0.5310155730146113
# alpha:  0.01 ; loc:  30.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0001_loc_0004
# rmse_f:  0.548703929766781
# rmse_a:  0.5020104817580788
# alpha:  0.01 ; loc:  40.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0001_loc_0005
# rmse_f:  0.5457664967974298
# rmse_a:  0.49926079077944907
# alpha:  0.01 ; loc:  50.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0001_loc_0006
# rmse_f:  0.5384493167523422
# rmse_a:  0.4930799388785463
# alpha:  0.01 ; loc:  60.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0001_loc_0007
# rmse_f:  0.5353400962964577
# rmse_a:  0.48978084610660916
# alpha:  0.02 ; loc:  5.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0002_loc_0000
# rmse_f:  0.981486556364634
# rmse_a:  0.9223720217910151
# alpha:  0.02 ; loc:  10.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0002_loc_0001
# rmse_f:  0.6172998288359771
# rmse_a:  0.5693287120166527
# alpha:  0.02 ; loc:  15.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0002_loc_0002
# rmse_f:  0.5811616526191319
# rmse_a:  0.5327581785836724
# alpha:  0.02 ; loc:  20.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0002_loc_0003
# rmse_f:  0.567690479033269
# rmse_a:  0.5178585214047223
# alpha:  0.02 ; loc:  30.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0002_loc_0004
# rmse_f:  0.5610139506922992
# rmse_a:  0.5120676101029564
# alpha:  0.02 ; loc:  40.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0002_loc_0005
# rmse_f:  0.5457177957823172
# rmse_a:  0.4986722853273561
# alpha:  0.02 ; loc:  50.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0002_loc_0006
# rmse_f:  0.5306922291250578
# rmse_a:  0.48594313198387923
# alpha:  0.02 ; loc:  60.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0002_loc_0007
# rmse_f:  0.5261571714726508
# rmse_a:  0.48074631746447266
# alpha:  0.04 ; loc:  5.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0003_loc_0000
# rmse_f:  0.9868788786416256
# rmse_a:  0.9251727681890743
# alpha:  0.04 ; loc:  10.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0003_loc_0001
# rmse_f:  0.6132279724306354
# rmse_a:  0.5632298348715943
# alpha:  0.04 ; loc:  15.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0003_loc_0002
# rmse_f:  0.5651039520902725
# rmse_a:  0.5162495881257012
# alpha:  0.04 ; loc:  20.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0003_loc_0003
# rmse_f:  0.5522335464177082
# rmse_a:  0.5031239705627912
# alpha:  0.04 ; loc:  30.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0003_loc_0004
# rmse_f:  0.5321187006554622
# rmse_a:  0.4854743308532381
# alpha:  0.04 ; loc:  40.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0003_loc_0005
# rmse_f:  0.5415859173011709
# rmse_a:  0.4932057104962963
# alpha:  0.04 ; loc:  50.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0003_loc_0006
# rmse_f:  0.532676921031255
# rmse_a:  0.4851447497599345
# alpha:  0.04 ; loc:  60.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0003_loc_0007
# rmse_f:  0.509223733830928
# rmse_a:  0.4639251280844685
# alpha:  0.08 ; loc:  5.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0004_loc_0000
# rmse_f:  0.9510622244947321
# rmse_a:  0.8840207677424258
# alpha:  0.08 ; loc:  10.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0004_loc_0001
# rmse_f:  0.6222176301721972
# rmse_a:  0.5678250165493837
# alpha:  0.08 ; loc:  15.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0004_loc_0002
# rmse_f:  0.5751188293175453
# rmse_a:  0.5227247088926911
# alpha:  0.08 ; loc:  20.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0004_loc_0003
# rmse_f:  0.5385343963658489
# rmse_a:  0.48950642370959535
# alpha:  0.08 ; loc:  30.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0004_loc_0004
# rmse_f:  0.5308718194743542
# rmse_a:  0.48170258417158357
# alpha:  0.08 ; loc:  40.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0004_loc_0005
# rmse_f:  0.5197440534331401
# rmse_a:  0.47225429374070454
# alpha:  0.08 ; loc:  50.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0004_loc_0006
# rmse_f:  0.5119559591586033
# rmse_a:  0.46596698962755295
# alpha:  0.08 ; loc:  60.0
# /home/travisharty/Documents/python_code/multi_loc/notebooks/RK_tune/fine_obs/stdrd_loc/inf_0004_loc_0007
# rmse_f:  0.5184846441608842
# rmse_a:  0.471163055327267

# %%
this_path = os.path.join(stdrd_dir, 'rmse_array_f.npy')
np.save(this_path, rmse_array_f)

this_path = os.path.join(stdrd_dir, 'std_array_f.npy')
np.save(this_path, std_array_f)

this_path = os.path.join(stdrd_dir, 'rmse_array_a.npy')
np.save(this_path, rmse_array_a)

this_path = os.path.join(stdrd_dir, 'std_array_a.npy')
np.save(this_path, std_array_a)

# %%
imshow(rmse_array_f)
